# %%
import subprocess

cmd = [
    'python', 'train.py',
    '--img', '1280',
    '--batch', '16',
    '--epochs', '100',
    '--data', 'car.yaml',
    '--cfg', 'models/yolov5n.yaml',
    '--weights', '',  # 사전 학습 가중치 없이 scratch로 학습
    '--hyp', 'data/hyps/hyp.scratch-med.yaml',
    '--name', 'yolov5n_scratch_med'
]

with subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1, universal_newlines=True) as p:
    for line in p.stdout:
        print(line, end='')
